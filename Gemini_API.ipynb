# %%
from google import genai


client = genai.Client(api_key="AIzaSyDfwR-WDUPDi3DufwRVoiv5oESjIOw3YyQ")

# %%
    from docx import Document
    import os

    def read_doc_and_store(file_path):
        try:
            document = Document(file_path)
            data = [paragraph.text for paragraph in document.paragraphs]
            return data
        except Exception as e:
           return f"An error occurred: {e}"

    folder_path = 'Fluid Stories'

    theme_list = []

    for root, dirs, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            data = read_doc_and_store(file_path)
            data_str = "Please return a one sentence summary of the following story. And please return the top two themes from the story\n".join(data) 
            response = client.models.generate_content(
            model="gemini-2.0-flash", contents=data_str)
            print(response.text)
# Out:
# Here's a summary and the themes from the story:
#
# **One-sentence summary:** A mischievous six-year-old's love for butter leads to a clandestine operation involving a stolen stick, a paper replacement, and a humorous confrontation with her parents, ultimately shaping her future personality.
#
# **Top two themes:**
#
# 1.  **Childhood Impulsivity/Innocence vs. Adult Authority:** The story highlights the clash between a child's uninhibited desires (eating butter) and the boundaries set by parental figures. The narrator's naive logic and the lengths she goes to satisfy her cravings are contrasted with her parents' reactions, creating a humorous yet relatable conflict.
#
# ...

# %%
type(response.text)
print(response.text)
